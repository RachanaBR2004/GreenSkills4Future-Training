# %% [markdown]
# #

# %%
def calculate_carbon_footprint(energy_consumption,emission_factor):
    return energy_consumption*emission_factor
energy_consumption=1000
emission_factor=0.475
carbon_footprint=calculate_carbon_footprint(energy_consumption,emission_factor)
print(f"carbon footprint:{carbon_footprint} kg CO2")
# Out:
# carbon footprint:475.0 kg CO2

# %%
cities=[
    {"name": "city A", "carbon_footprint":500},
    {"name": "city B", "carbon_footprint":350},
    {"name": "city C", "carbon_footprint":600},
    {"name": "city D", "carbon_footprint":200},
]
sustainability_threshold=400
sustainable_cities=list(filter(lambda city:city["carbon_footprint"]<sustainability_threshold,cities))
print("sustainable cities:")
for city in sustainable_cities:
    print(city["name"])
# Out:
# sustainable cities:
# city B
# city D

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

# %%
person=Person("bharat",13)

# %%
person.age
# Out:
# 13

# %%
class car:
    wheels=4
    def __init__(self,make,year):
        self.make=make
        self.age=year
    def start_engine(Self):
        print("engine started")
    @classmethod
    def get_wheels(cls):
        return cls_wheels

# %%
class person:
    def __init__(self):
        self.__name=age

# %%
#inheritance
class vehicle:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model

# %%
import pandas as pd
data={
    "name": ["a", "b", "c"],
    "age":[12,15,18],
    "subject": ["math"," sci", "social"]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   name  age subject
# 0    a   12    math
# 1    b   15     sci
# 2    c   18  social

# %%
#plotting
import pandas as pd

renewable_sources = ['Solar','Wind','Hydro','Geothermal', 'Tidal']
rs = pd.Series(renewable_sources)

# %%
import pandas as pd

# Create DataFrame from dictionary
df = pd.DataFrame({
    'Project': ['Solar Farm', 'Wind Turbine', 'Hydro Plant', 'Geothermal Station', 'Tidal Plant'],
    'Technology': ['Solar', 'Wind', 'Hydro', 'Geothermal', 'Tidal'],
    'Capacity(MW)': [150, 300, 200, 50, 175],
    'Cost(Million $)': [200, 400, 350, 100, 250],
    'Location': ['California', 'Texas', 'Washington', 'Nevada', 'LA'],
    'YOC': [2023, 2022, 2021, 2023, 2022]
})

# Filtering based on capacity
high_capacity = df[df['Capacity(MW)'] > 150]
print(f'High Capacity Projects are:\n{high_capacity}\n')

# Filtering based on cost
high_cost = df[df['Cost(Million $)'] > 100]
print(f'High Cost Projects are:\n{high_cost}')
# Out:
# High Capacity Projects are:
#         Project Technology  Capacity(MW)  Cost(Million $)    Location   YOC
# 1  Wind Turbine       Wind           300              400       Texas  2022
# 2   Hydro Plant      Hydro           200              350  Washington  2021
# 4   Tidal Plant      Tidal           175              250          LA  2022
#
# High Cost Projects are:
#         Project Technology  Capacity(MW)  Cost(Million $)    Location   YOC
# 0    Solar Farm      Solar           150              200  California  2023
# 1  Wind Turbine       Wind           300              400       Texas  2022
# 2   Hydro Plant      Hydro           200              350  Washington  2021
# 4   Tidal Plant      Tidal           175              250          LA  2022

# %%
import numpy as np
a=np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
import pandas as pd

renewable_sources = ['Solar','Wind','Hydro','Geothermal','Tidal']
rs = pd.Series(renewable_sources)
rs
# Out:
# 0         Solar
# 1          Wind
# 2         Hydro
# 3    Geothermal
# 4         Tidal
# dtype: object

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
print("Array is:", arr)
# Out:
# Array is: [10 20 30 40 50]

# %%
import numpy as np
arr = np.array([[[10, 20, 30, 40],[11,20,55,36],[45,88,78,99]]])
print("Array is:", arr)
# Out:
# Array is: [[[10 20 30 40]
#   [11 20 55 36]
#   [45 88 78 99]]]

# %%
import random

number = random.randint(1, 10)
print("Random number:", number)
# Out:
# Random number: 7

# %%
import random

fruits = ["apple", "banana", "mango", "orange"]
choice = random.choice(fruits)
print("Random fruit:", choice)
# Out:
# Random fruit: banana

# %%
import numpy as np
data = [10, 12, 23, 23, 16, 23, 21, 16]
std_deviation = np.std(data)
mean=np.mean(data)
print(f"std_deviation:{std_deviation},\nmean:{mean}")
# Out:
# std_deviation:4.898979485566356,
# mean:18.0

# %%
import pandas as pd
import numpy as np
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}
energy_df=pd.DataFrame(data)
energy_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
energy_df.isnull().sum()
# Out:
# Energy Source               0
# Energy Consumption (MWh)    2
# Cost (Million $)            2
# dtype: int64

# %%
cleaned_df=energy_df.dropna()
cleaned_df
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    2450.0             400.0
# 2    Hydropower                    2900.0             250.0
# 3    Geothermal                    2450.0             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0             250.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
energy_df[['Energy Consumption (MWh)','Cost (Million $)']]=scaler.fit_transform(energy_df[['Energy Consumption (MWh)','Cost (Million $)']])
energy_df
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                     0.000               0.2
# 1          Wind                     0.625               1.0
# 2    Hydropower                     0.850               0.4
# 3    Geothermal                     0.625               0.0
# 4       Biomass                     0.650               0.4
# 5       Nuclear                     1.000               0.4

# %%
energy_encoded_df=pd.get_dummies(energy_df,columns=['Energy Source'])
energy_encoded_df
# Out:
#    Energy Consumption (MWh)  Cost (Million $)  Energy Source_Biomass  \
# 0                    1200.0             200.0                  False
# 1                       NaN             400.0                  False
# 2                    2900.0               NaN                  False
# 3                       NaN             150.0                  False
# 4                    2500.0             250.0                   True
# 5                    3200.0               NaN                  False
#
#    Energy Source_Geothermal  Energy Source_Hydropower  Energy Source_Nuclear  \
# 0                     False                     False                  False
# 1                     False                     False                  False
# 2                     False                      True                  False
# 3                      True                     False                  False
# 4                     False                     False                  False
# ...

# %%
months=['Jan','Feb','Mar','Apr','May','Jun']
energy_cons=[1200,1300,110,1500,1400,1600]

# %%
import matplotlib.pyplot as plt
plt.plot(months,energy_cons,marker='o',linestyle='dashed',color='red')
plt.title('energy consumption vs month')
plt.xlabel('Months')
plt.ylabel('energy consumption(MWh)')
plt.show()

# %%
energy_sources=['solar','wind','hydropower','biomass']
values=[1200,3400,2900,2500]
plt.bar(energy_sources,values,color='magenta')
plt.title('enery sources vs values')
plt.xlabel('energy sources')
plt.ylabel('values')
plt.show()

# %%
carbon_emission=[200,500,450,300]
plt.scatter(values,carbon_emission,color='red')
plt.show()

# %%
plt.bar(energy_sources,values,color='orange',edgecolor='black',linewidth=2)
plt.title("customized bar plot")
plt.xlabel('Energy sources',fontsize=12)
plt.ylabel('values',fontsize=12)
plt.grid(True,linestyle='--',alpha=0.7)
plt.legend(['Energy_sources'])
plt.show()

# %%
import seaborn as sns
import pandas as pd
data={"Solar":[1200,1500,1300],
      "Wind":[3400,3600,3200],
      "Hydropower":[2900,3100,2800],
      "Biomass":[2500,2700,2400]}
df=pd.DataFrame(data)
df
# Out:
#    Solar  Wind  Hydropower  Biomass
# 0   1200  3400        2900     2500
# 1   1500  3600        3100     2700
# 2   1300  3200        2800     2400

# %%
sns.pairplot(df)
plt.show()

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#                Solar      Wind  Hydropower   Biomass
# Solar       1.000000  0.654654    0.251005  0.785714
# Wind        0.654654  1.000000    0.896050  0.981981
# Hydropower  0.251005  0.896050    1.000000  0.796004
# Biomass     0.785714  0.981981    0.796004  1.000000

# %%
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',linewidth=0.2)
plt.title('correlation between energy sources')
plt.xlabel('energy1')
plt.ylabel('energy2')

plt.show()

# %%
sns.boxplot(data=df)
plt.show()

# %%
sns.violinplot(data=df)
plt.show()
